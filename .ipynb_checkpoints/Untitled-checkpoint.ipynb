# %%
import matplotlib.pyplot as plt
import book_plot as bp
from __future__ import division
import sys
import collections
# %matplotlib inline

# %%
# n=20
# a=[1./n]*n
m = [ 10, 4, 3, 17, 12, 13]#5, 12, 16, 4]#,
plt.figure(figsize=(17,6),dpi=150)
for j in m:
    max_a = max(a)
    for i in range(3):
        b=1.5-i*0.25
        a[j-i]*=b
        a[j+i]*=b
#         a[j-i]=max(a[j-i],a[j-i]*b)
#         a[j+i]=max(a[j+i],a[j+i]*b)
    a = [i*5/sum(a) for i in a]
    plt.subplot(len(m)/2,2,m.index(j)+1)
    bp.bar_plot(a,title='step{}'.format(m.index(j)+1))

# %%
a[13]=max(a)
a[14]=max(a)
a[15]=max(a)
bp.bar_plot(a)
