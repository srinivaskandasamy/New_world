# %%
from Tkinter import *
from __future__ import division
import tkFileDialog
from math import cos, pi, fabs
from numpy import sign,arange, sin
import sys
from PIL import Image, ImageTk
from boundaries import boundaries
from walls import walls
from Sphero import Sphero
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg, NavigationToolbar2TkAgg

# Addition of a Next button in the GUI window
def start():   # For the next button
#     fp = open("robot_trajectory3.txt","w")
    global pose, control, constraints, loop, radius, wall_width, world_size, flag
    scale = 520
    loop = not(loop)
    i=0
    while loop and i<=50:
        print "Entered"
        posep = pose
        print "Prediction to start with pose",pose
        pose = s.motion(pose,control,0.01)
        print "Prediction is completed",pose
        print "Check collision"
        f=s.draw(pose)
        pose = s.check_collision(constraints, pose, posep, flag)
        print "Collision detection is completed",pose
        f=s.draw(pose[0])
        robot_map(0.025+(pose[0][0])/scale,0.9-(pose[0][1])/scale,pose[1],radius/scale,wall_width/scale)
        root.update()
        print "Tada {0} \t {1} \t {2} \t{3}".format(pose[0][0],pose[0][1],pose[0][2],pose[1])
        pose = pose[0]
        i = i+1

def stop():
    global loop
    loop = not(loop)
    
def boost():
    global control
    control[0] = control[0] + 50
    if control[0] <= 0:
        control[0] =0

def slow():
    global control
    control[0] = control[0] - 50
    if control[0] <= 0:
        control[0] =0

def correct_wall():
    global pose, control, loop, flag
    loop = not(loop)
    pose = [100,150,pi/4]
    control = [100,0]
    loop = 0
    flag = 1
        
def robot_map(cx,cy,wall_type,rad,ww):
    if wall_type == 1:
        ax1 = fig.add_axes([cx-rad-ww, cy, ww, ww*3]) # GUI rectangle creation
        ax1.set_axis_off()
        ax2 = fig.add_axes([cx-rad-ww, cy-ww*3, ww, ww*3])
        ax2.set_axis_off()
        cmap1 = mpl.cm.gray
        cmap2 = mpl.cm.Greys
        norm = mpl.colors.Normalize()
        cb1 = mpl.colorbar.ColorbarBase(ax1, cmap=cmap1,
                                       norm=norm,
                                       orientation='vertical')
        cb1.outline.set_visible(False)
        cb1 = mpl.colorbar.ColorbarBase(ax2, cmap=cmap2,
                                       norm=norm,
                                       orientation='vertical')
        cb1.outline.set_visible(False)
        plt.gcf().canvas.draw()
        
    elif wall_type == 2:
        ax1 = fig.add_axes([cx, cy-rad, ww*3, ww]) # GUI rectangle creation
        ax1.set_axis_off()
        ax2 = fig.add_axes([cx-ww*3, cy-rad, ww*3, ww])
        ax2.set_axis_off()
        cmap1 = mpl.cm.gray
        cmap2 = mpl.cm.Greys
        norm = mpl.colors.Normalize()
        cb1 = mpl.colorbar.ColorbarBase(ax1, cmap=cmap1,
                                       norm=norm,
                                       orientation='horizontal')
        cb1.outline.set_visible(False)
        cb1 = mpl.colorbar.ColorbarBase(ax2, cmap=cmap2,
                                       norm=norm,
                                       orientation='horizontal')
        cb1.outline.set_visible(False)
        plt.gcf().canvas.draw()
        
    elif wall_type == 3:
        ax1 = fig.add_axes([cx+rad, cy, ww, ww*3]) # GUI rectangle creation
        ax1.set_axis_off()
        ax2 = fig.add_axes([cx+rad, cy-ww*3, ww, ww*3])
        ax2.set_axis_off()
        cmap1 = mpl.cm.gray
        cmap2 = mpl.cm.Greys
        norm = mpl.colors.Normalize()
        cb1 = mpl.colorbar.ColorbarBase(ax1, cmap=cmap1,
                                       norm=norm,
                                       orientation='vertical')
        cb1.outline.set_visible(False)
        cb1 = mpl.colorbar.ColorbarBase(ax2, cmap=cmap2,
                                       norm=norm,
                                       orientation='vertical')
        cb1.outline.set_visible(False)
        plt.gcf().canvas.draw()
        
    elif wall_type == 4:
        ax1 = fig.add_axes([cx, cy+rad+ww, ww*3, ww]) # GUI rectangle creation
        ax1.set_axis_off()
        ax2 = fig.add_axes([cx-ww*3, cy+rad+ww, ww*3, ww])
        ax2.set_axis_off()
        cmap1 = mpl.cm.gray
        cmap2 = mpl.cm.Greys
        norm = mpl.colors.Normalize()
        cb1 = mpl.colorbar.ColorbarBase(ax1, cmap=cmap1,
                                       norm=norm,
                                       orientation='horizontal')
        cb1.outline.set_visible(False)
        cb1 = mpl.colorbar.ColorbarBase(ax2, cmap=cmap2,
                                       norm=norm,
                                       orientation='horizontal')
        cb1.outline.set_visible(False)
        plt.gcf().canvas.draw()
        
    else:
        pass
        
if __name__ =="__main__":

    # Specifications of the world
    origin = (2,2)
    world_size = (498, 498)   # 750,750
    wall_width = 10
    radius = 10
    plotShift = 0
    flag = 0 # For wall correction
    wall_location =[[origin[0]+(world_size[0])/4,origin[1]+wall_width,origin[0]+(world_size[0])/4,origin[1]+wall_width+(world_size[1])*3/4],
                    [origin[0]+(world_size[0])/2,origin[1]+wall_width+(world_size[1])*1/4,origin[0]+(world_size[0])/2,origin[1]-wall_width+world_size[1]],
                    [origin[0]+(world_size[0])*3/4,origin[1]+wall_width,origin[0]+(world_size[0])*3/4,origin[1]+wall_width+(world_size[1])*3/4]] 
    
    #Initialization of boundary and walls
    sri = boundaries(world_size,wall_width) 
    mw = walls(wall_width,wall_location)
    
    # Intialization of GUI
    root = Tk()
    root.title("Ball in a maze")
    frame1 = Frame(root)
    frame1.pack()
    w = Canvas(frame1,width=500,height=500,bg="white")
    w.pack(side=LEFT)
    
    
    # Robot map
    r = Canvas(frame1,width=500,height=500,bg="white")
    r.pack(side=RIGHT)
    fig = plt.figure(figsize=(6.15,6.15),facecolor='w',edgecolor='w')
    canvas = FigureCanvasTkAgg(fig, master=r)
    canvas.get_tk_widget().pack(side=RIGHT)
    
    
    # Creating world objects
    sri.draw(origin,w)
    mw.draw(wall_width,wall_location,w)
    parray = sri.boundary_grid(origin,w)
    warray = mw.wall_grid(wall_width,wall_location,w)
    
    # Creating Sphero robot
    s = Sphero(w)
    constraints = s.sphero_constraint(origin,wall_width,world_size,wall_location)
    
    pose = [100,150,pi/4]
    control = [100,0]
    loop = 0
    frame2 = Frame(root)
    frame2.pack()
    start = Button(frame2,text="START", width=10,command=start)
    start.grid(row=0,column=0)
    stop = Button(frame2,text="STOP",width=10,command=stop)
    stop.grid(row=0,column=1)
    boost = Button(frame2,text="BOOST", width=10,command=boost)
    boost.grid(row=0,column=2)
    slow = Button(frame2,text="SLOW", width=10,command=slow)
    slow.grid(row=0,column=3)
    wc = Button(frame2,text="Wall Correction", width=15,command=correct_wall)
    wc.grid(row=0,column=4)
    
    # Draw GUI
    root.mainloop()
# Out:
# Entered
# Prediction to start with pose [100, 150, 0.7853981633974483]
# Prediction is completed [102.12132034355965, 152.12132034355963, 0.7853981633974483]
# Check collision
# Collision detection is completed ([102.12132034355965, 152.12132034355963, 0.7853981633974483], 0, [0, 0, 0])
# Tada 102.121320344 	 152.121320344 	 0.785398163397 	0
# Entered
# Prediction to start with pose [102.12132034355965, 152.12132034355963, 0.7853981633974483]
# Prediction is completed [104.24264068711929, 154.24264068711926, 0.7853981633974483]
# Check collision
# Collision detection is completed ([104.24264068711929, 154.24264068711926, 0.7853981633974483], 0, [0, 0, 0])
# Tada 104.242640687 	 154.242640687 	 0.785398163397 	0
# Entered
# Prediction to start with pose [104.24264068711929, 154.24264068711926, 0.7853981633974483]
# Prediction is completed [106.36396103067894, 156.3639610306789, 0.7853981633974483]
# Check collision
# Collision detection is completed ([106.36396103067894, 156.3639610306789, 0.7853981633974483], 0, [0, 0, 0])
# Tada 106.363961031 	 156.363961031 	 0.785398163397 	0
# Entered
# Prediction to start with pose [106.36396103067894, 156.3639610306789, 0.7853981633974483]
# Prediction is completed [108.48528137423858, 158.48528137423853, 0.7853981633974483]
# Check collision
# Collision detection is completed ([108.48528137423858, 158.48528137423853, 0.7853981633974483], 0, [0, 0, 0])
# Tada 108.485281374 	 158.485281374 	 0.785398163397 	0
# Entered
# Prediction to start with pose [108.48528137423858, 158.48528137423853, 0.7853981633974483]
# Prediction is completed [110.60660171779823, 160.60660171779816, 0.7853981633974483]
# Check collision
# Collision detection is completed ([110.60660171779823, 160.60660171779816, 0.7853981633974483], 0, [0, 0, 0])
# Tada 110.606601718 	 160.606601718 	 0.785398163397 	0
# Entered
# Prediction to start with pose [110.60660171779823, 160.60660171779816, 0.7853981633974483]
# Prediction is completed [112.72792206135787, 162.7279220613578, 0.7853981633974483]
# Check collision
# Collision detection is completed ([111.5, 161.49999999999991, 2.356194490192345], 3, [-1, 0, -111.5])
# Tada 111.5 	 161.5 	 2.35619449019 	3
# Entered
# Prediction to start with pose [111.5, 161.49999999999991, 2.356194490192345]
# Prediction is completed [109.37867965644035, 163.62132034355955, 2.356194490192345]
# Check collision
# Collision detection is completed ([109.37867965644035, 163.62132034355955, 2.356194490192345], 0, [0, 0, 0])
# Tada 109.378679656 	 163.621320344 	 2.35619449019 	0
# Entered
# Prediction to start with pose [109.37867965644035, 163.62132034355955, 2.356194490192345]
# Prediction is completed [107.25735931288071, 165.74264068711918, 2.356194490192345]
# Check collision
# Collision detection is completed ([107.25735931288071, 165.74264068711918, 2.356194490192345], 0, [0, 0, 0])
# Tada 107.257359313 	 165.742640687 	 2.35619449019 	0
# Entered
# Prediction to start with pose [107.25735931288071, 165.74264068711918, 2.356194490192345]
# Prediction is completed [105.13603896932106, 167.8639610306788, 2.356194490192345]
# Check collision
# Collision detection is completed ([105.13603896932106, 167.8639610306788, 2.356194490192345], 0, [0, 0, 0])
# Tada 105.136038969 	 167.863961031 	 2.35619449019 	0
# Entered
# Prediction to start with pose [105.13603896932106, 167.8639610306788, 2.356194490192345]
# Prediction is completed [103.01471862576142, 169.98528137423844, 2.356194490192345]
# Check collision
# Collision detection is completed ([103.01471862576142, 169.98528137423844, 2.356194490192345], 0, [0, 0, 0])
# Tada 103.014718626 	 169.985281374 	 2.35619449019 	0
# Entered
# Prediction to start with pose [103.01471862576142, 169.98528137423844, 2.356194490192345]
# Prediction is completed [100.89339828220177, 172.10660171779807, 2.356194490192345]
# Check collision
# Collision detection is completed ([100.89339828220177, 172.10660171779807, 2.356194490192345], 0, [0, 0, 0])
# Tada 100.893398282 	 172.106601718 	 2.35619449019 	0
# Entered
# Prediction to start with pose [100.89339828220177, 172.10660171779807, 2.356194490192345]
# Prediction is completed [98.77207793864213, 174.2279220613577, 2.356194490192345]
# Check collision
# Collision detection is completed ([98.77207793864213, 174.2279220613577, 2.356194490192345], 0, [0, 0, 0])
# Tada 98.7720779386 	 174.227922061 	 2.35619449019 	0
# Entered
# Prediction to start with pose [98.77207793864213, 174.2279220613577, 2.356194490192345]
# Prediction is completed [96.65075759508248, 176.34924240491733, 2.356194490192345]
# Check collision
# Collision detection is completed ([96.65075759508248, 176.34924240491733, 2.356194490192345], 0, [0, 0, 0])
# Tada 96.6507575951 	 176.349242405 	 2.35619449019 	0
# Entered
# Prediction to start with pose [96.65075759508248, 176.34924240491733, 2.356194490192345]
# Prediction is completed [94.52943725152284, 178.47056274847696, 2.356194490192345]
# Check collision
# Collision detection is completed ([94.52943725152284, 178.47056274847696, 2.356194490192345], 0, [0, 0, 0])
# Tada 94.5294372515 	 178.470562748 	 2.35619449019 	0
# Entered
# Prediction to start with pose [94.52943725152284, 178.47056274847696, 2.356194490192345]
# Prediction is completed [92.40811690796319, 180.5918830920366, 2.356194490192345]
# Check collision
# Collision detection is completed ([92.40811690796319, 180.5918830920366, 2.356194490192345], 0, [0, 0, 0])
# Tada 92.408116908 	 180.591883092 	 2.35619449019 	0
# Entered
# Prediction to start with pose [92.40811690796319, 180.5918830920366, 2.356194490192345]
# Prediction is completed [90.28679656440355, 182.71320343559623, 2.356194490192345]
# Check collision
# Collision detection is completed ([90.28679656440355, 182.71320343559623, 2.356194490192345], 0, [0, 0, 0])
# Tada 90.2867965644 	 182.713203436 	 2.35619449019 	0
# Entered
# Prediction to start with pose [90.28679656440355, 182.71320343559623, 2.356194490192345]
# Prediction is completed [88.1654762208439, 184.83452377915586, 2.356194490192345]
# Check collision
# Collision detection is completed ([88.1654762208439, 184.83452377915586, 2.356194490192345], 0, [0, 0, 0])
# Tada 88.1654762208 	 184.834523779 	 2.35619449019 	0
# Entered
# Prediction to start with pose [88.1654762208439, 184.83452377915586, 2.356194490192345]
# Prediction is completed [86.04415587728425, 186.9558441227155, 2.356194490192345]
# Check collision
# Collision detection is completed ([86.04415587728425, 186.9558441227155, 2.356194490192345], 0, [0, 0, 0])
# Tada 86.0441558773 	 186.955844123 	 2.35619449019 	0
# Entered
# Prediction to start with pose [86.04415587728425, 186.9558441227155, 2.356194490192345]
# Prediction is completed [83.92283553372461, 189.07716446627512, 2.356194490192345]
# Check collision
# Collision detection is completed ([83.92283553372461, 189.07716446627512, 2.356194490192345], 0, [0, 0, 0])
# Tada 83.9228355337 	 189.077164466 	 2.35619449019 	0
# Entered
# Prediction to start with pose [83.92283553372461, 189.07716446627512, 2.356194490192345]
# Prediction is completed [81.80151519016496, 191.19848480983475, 2.356194490192345]
# Check collision
# Collision detection is completed ([81.80151519016496, 191.19848480983475, 2.356194490192345], 0, [0, 0, 0])
# Tada 81.8015151902 	 191.19848481 	 2.35619449019 	0
# Entered
# Prediction to start with pose [81.80151519016496, 191.19848480983475, 2.356194490192345]
# Prediction is completed [79.68019484660532, 193.31980515339438, 2.356194490192345]
# Check collision
# Collision detection is completed ([79.68019484660532, 193.31980515339438, 2.356194490192345], 0, [0, 0, 0])
# Tada 79.6801948466 	 193.319805153 	 2.35619449019 	0
# Entered
# Prediction to start with pose [79.68019484660532, 193.31980515339438, 2.356194490192345]
# Prediction is completed [77.55887450304567, 195.44112549695402, 2.356194490192345]
# Check collision
# Collision detection is completed ([77.55887450304567, 195.44112549695402, 2.356194490192345], 0, [0, 0, 0])
# Tada 77.558874503 	 195.441125497 	 2.35619449019 	0
# Entered
# Prediction to start with pose [77.55887450304567, 195.44112549695402, 2.356194490192345]
# Prediction is completed [75.43755415948603, 197.56244584051365, 2.356194490192345]
# Check collision
# Collision detection is completed ([75.43755415948603, 197.56244584051365, 2.356194490192345], 0, [0, 0, 0])
# Tada 75.4375541595 	 197.562445841 	 2.35619449019 	0
# Entered
# Prediction to start with pose [75.43755415948603, 197.56244584051365, 2.356194490192345]
# Prediction is completed [73.31623381592638, 199.68376618407328, 2.356194490192345]
# Check collision
# Collision detection is completed ([73.31623381592638, 199.68376618407328, 2.356194490192345], 0, [0, 0, 0])
# Tada 73.3162338159 	 199.683766184 	 2.35619449019 	0
# Entered
# Prediction to start with pose [73.31623381592638, 199.68376618407328, 2.356194490192345]
# Prediction is completed [71.19491347236674, 201.8050865276329, 2.356194490192345]
# Check collision
# Collision detection is completed ([71.19491347236674, 201.8050865276329, 2.356194490192345], 0, [0, 0, 0])
# Tada 71.1949134724 	 201.805086528 	 2.35619449019 	0
# Entered
# Prediction to start with pose [71.19491347236674, 201.8050865276329, 2.356194490192345]
# Prediction is completed [69.07359312880709, 203.92640687119254, 2.356194490192345]
# Check collision
# Collision detection is completed ([69.07359312880709, 203.92640687119254, 2.356194490192345], 0, [0, 0, 0])
# Tada 69.0735931288 	 203.926406871 	 2.35619449019 	0
# Entered
# Prediction to start with pose [69.07359312880709, 203.92640687119254, 2.356194490192345]
# Prediction is completed [66.95227278524744, 206.04772721475217, 2.356194490192345]
# Check collision
# Collision detection is completed ([66.95227278524744, 206.04772721475217, 2.356194490192345], 0, [0, 0, 0])
# Tada 66.9522727852 	 206.047727215 	 2.35619449019 	0
# Entered
# Prediction to start with pose [66.95227278524744, 206.04772721475217, 2.356194490192345]
# Prediction is completed [64.8309524416878, 208.1690475583118, 2.356194490192345]
# Check collision
# Collision detection is completed ([64.8309524416878, 208.1690475583118, 2.356194490192345], 0, [0, 0, 0])
# Tada 64.8309524417 	 208.169047558 	 2.35619449019 	0
# Entered
# Prediction to start with pose [64.8309524416878, 208.1690475583118, 2.356194490192345]
# Prediction is completed [62.709632098128154, 210.29036790187143, 2.356194490192345]
# Check collision
# Collision detection is completed ([62.709632098128154, 210.29036790187143, 2.356194490192345], 0, [0, 0, 0])
# Tada 62.7096320981 	 210.290367902 	 2.35619449019 	0
# Entered
# Prediction to start with pose [62.709632098128154, 210.29036790187143, 2.356194490192345]
# Prediction is completed [60.58831175456851, 212.41168824543107, 2.356194490192345]
# Check collision
# Collision detection is completed ([60.58831175456851, 212.41168824543107, 2.356194490192345], 0, [0, 0, 0])
# Tada 60.5883117546 	 212.411688245 	 2.35619449019 	0
# Entered
# Prediction to start with pose [60.58831175456851, 212.41168824543107, 2.356194490192345]
# Prediction is completed [58.46699141100886, 214.5330085889907, 2.356194490192345]
# Check collision
# Collision detection is completed ([58.46699141100886, 214.5330085889907, 2.356194490192345], 0, [0, 0, 0])
# Tada 58.466991411 	 214.533008589 	 2.35619449019 	0
# Entered
# Prediction to start with pose [58.46699141100886, 214.5330085889907, 2.356194490192345]
# Prediction is completed [56.34567106744922, 216.65432893255033, 2.356194490192345]
# Check collision
# Collision detection is completed ([56.34567106744922, 216.65432893255033, 2.356194490192345], 0, [0, 0, 0])
# Tada 56.3456710674 	 216.654328933 	 2.35619449019 	0
# Entered
# Prediction to start with pose [56.34567106744922, 216.65432893255033, 2.356194490192345]
# Prediction is completed [54.22435072388957, 218.77564927610996, 2.356194490192345]
# Check collision
# Collision detection is completed ([54.22435072388957, 218.77564927610996, 2.356194490192345], 0, [0, 0, 0])
# Tada 54.2243507239 	 218.775649276 	 2.35619449019 	0
# Entered
# Prediction to start with pose [54.22435072388957, 218.77564927610996, 2.356194490192345]
# Prediction is completed [52.103030380329926, 220.8969696196696, 2.356194490192345]
# Check collision
# Collision detection is completed ([52.103030380329926, 220.8969696196696, 2.356194490192345], 0, [0, 0, 0])
# Tada 52.1030303803 	 220.89696962 	 2.35619449019 	0
# Entered
# Prediction to start with pose [52.103030380329926, 220.8969696196696, 2.356194490192345]
# Prediction is completed [49.98171003677028, 223.01828996322922, 2.356194490192345]
# Check collision
# Collision detection is completed ([49.98171003677028, 223.01828996322922, 2.356194490192345], 0, [0, 0, 0])
# Tada 49.9817100368 	 223.018289963 	 2.35619449019 	0
# Entered
# Prediction to start with pose [49.98171003677028, 223.01828996322922, 2.356194490192345]
# Prediction is completed [47.860389693210635, 225.13961030678885, 2.356194490192345]
# Check collision
# Collision detection is completed ([47.860389693210635, 225.13961030678885, 2.356194490192345], 0, [0, 0, 0])
# Tada 47.8603896932 	 225.139610307 	 2.35619449019 	0
# Entered
# Prediction to start with pose [47.860389693210635, 225.13961030678885, 2.356194490192345]
# Prediction is completed [45.73906934965099, 227.26093065034848, 2.356194490192345]
# Check collision
# Collision detection is completed ([45.73906934965099, 227.26093065034848, 2.356194490192345], 0, [0, 0, 0])
# Tada 45.7390693497 	 227.26093065 	 2.35619449019 	0
# Entered
# Prediction to start with pose [45.73906934965099, 227.26093065034848, 2.356194490192345]
# Prediction is completed [43.617749006091344, 229.38225099390812, 2.356194490192345]
# Check collision
# Collision detection is completed ([43.617749006091344, 229.38225099390812, 2.356194490192345], 0, [0, 0, 0])
# Tada 43.6177490061 	 229.382250994 	 2.35619449019 	0
# Entered
# Prediction to start with pose [43.617749006091344, 229.38225099390812, 2.356194490192345]
# Prediction is completed [41.4964286625317, 231.50357133746775, 2.356194490192345]
# Check collision
# Collision detection is completed ([41.4964286625317, 231.50357133746775, 2.356194490192345], 0, [0, 0, 0])
# Tada 41.4964286625 	 231.503571337 	 2.35619449019 	0
# Entered
# Prediction to start with pose [41.4964286625317, 231.50357133746775, 2.356194490192345]
# Prediction is completed [39.37510831897205, 233.62489168102738, 2.356194490192345]
# Check collision
# Collision detection is completed ([39.37510831897205, 233.62489168102738, 2.356194490192345], 0, [0, 0, 0])
# Tada 39.375108319 	 233.624891681 	 2.35619449019 	0
# Entered
# Prediction to start with pose [39.37510831897205, 233.62489168102738, 2.356194490192345]
# Prediction is completed [37.25378797541241, 235.746212024587, 2.356194490192345]
# Check collision
# Collision detection is completed ([37.25378797541241, 235.746212024587, 2.356194490192345], 0, [0, 0, 0])
# Tada 37.2537879754 	 235.746212025 	 2.35619449019 	0
# Entered
# Prediction to start with pose [37.25378797541241, 235.746212024587, 2.356194490192345]
# Prediction is completed [35.13246763185276, 237.86753236814664, 2.356194490192345]
# Check collision
# Collision detection is completed ([35.13246763185276, 237.86753236814664, 2.356194490192345], 0, [0, 0, 0])
# Tada 35.1324676319 	 237.867532368 	 2.35619449019 	0
# Entered
# Prediction to start with pose [35.13246763185276, 237.86753236814664, 2.356194490192345]
# Prediction is completed [33.01114728829312, 239.98885271170627, 2.356194490192345]
# Check collision
# Collision detection is completed ([33.01114728829312, 239.98885271170627, 2.356194490192345], 0, [0, 0, 0])
# Tada 33.0111472883 	 239.988852712 	 2.35619449019 	0
# Entered
# Prediction to start with pose [33.01114728829312, 239.98885271170627, 2.356194490192345]
# Prediction is completed [30.889826944733475, 242.1101730552659, 2.356194490192345]
# Check collision
# Collision detection is completed ([30.889826944733475, 242.1101730552659, 2.356194490192345], 0, [0, 0, 0])
# Tada 30.8898269447 	 242.110173055 	 2.35619449019 	0
# Entered
# Prediction to start with pose [30.889826944733475, 242.1101730552659, 2.356194490192345]
# Prediction is completed [28.768506601173833, 244.23149339882553, 2.356194490192345]
# Check collision
# Collision detection is completed ([28.768506601173833, 244.23149339882553, 2.356194490192345], 0, [0, 0, 0])
# Tada 28.7685066012 	 244.231493399 	 2.35619449019 	0
# Entered
# Prediction to start with pose [28.768506601173833, 244.23149339882553, 2.356194490192345]
# Prediction is completed [26.64718625761419, 246.35281374238517, 2.356194490192345]
# Check collision
# Collision detection is completed ([26.64718625761419, 246.35281374238517, 2.356194490192345], 0, [0, 0, 0])
# Tada 26.6471862576 	 246.352813742 	 2.35619449019 	0
# Entered
# Prediction to start with pose [26.64718625761419, 246.35281374238517, 2.356194490192345]
# Prediction is completed [24.52586591405455, 248.4741340859448, 2.356194490192345]
# Check collision
# Collision detection is completed ([24.52586591405455, 248.4741340859448, 2.356194490192345], 0, [0, 0, 0])
# Tada 24.5258659141 	 248.474134086 	 2.35619449019 	0
# Entered
# Prediction to start with pose [24.52586591405455, 248.4741340859448, 2.356194490192345]
# Prediction is completed [22.404545570494907, 250.59545442950443, 2.356194490192345]
# Check collision
# Collision detection is completed ([22.404545570494907, 250.59545442950443, 2.356194490192345], 0, [0, 0, 0])
# Tada 22.4045455705 	 250.59545443 	 2.35619449019 	0
# Entered
# Prediction to start with pose [22.404545570494907, 250.59545442950443, 2.356194490192345]
# Prediction is completed [20.283225226935265, 252.71677477306406, 2.356194490192345]
# Check collision
# Collision detection is completed ([22.0, 250.99999999999935, 0.7853981633974483], 1, [1, 0, 22])
# Tada 22.0 	 251.0 	 0.785398163397 	1
# Entered
# Prediction to start with pose [22.0, 250.99999999999935, 0.7853981633974483]
# Prediction is completed [24.121320343559642, 253.12132034355898, 0.7853981633974483]
# Check collision
# Collision detection is completed ([24.121320343559642, 253.12132034355898, 0.7853981633974483], 0, [0, 0, 0])
# Tada 24.1213203436 	 253.121320344 	 0.785398163397 	0
# Entered
# Prediction to start with pose [24.121320343559642, 253.12132034355898, 0.7853981633974483]
# Prediction is completed [26.242640687119284, 255.2426406871186, 0.7853981633974483]
# Check collision
# Collision detection is completed ([26.242640687119284, 255.2426406871186, 0.7853981633974483], 0, [0, 0, 0])
# Tada 26.2426406871 	 255.242640687 	 0.785398163397 	0

# %%
import numpy as np
f = np.loadtxt(r"C:\Users\localadmin.TUD0035314\Documents\GitHub\New_world\robot_trajectory.txt")
print f[0:100]
